# %% [markdown]
# # Chapter 9: Interest Rate Risk

# %%
RSA = 30+30+70+40
print("the amount of rate sensitive assets is", RSA)
RSL = 40+30+20
print("the amount of rate sensitive liabilities is", RSL)
GAP = RSA-RSL
print("the repricing gap is", GAP)
delta_R = 0.01
delta_NII = GAP*delta_R
print("the change in net interest income is", delta_NII)
# Out:
# the amount of rate sensitive assets is 170
# the amount of rate sensitive liabilities is 90
# the repricing gap is 80
# the change in net interest income is 0.8

# %%
from copy import deepcopy

# Create a list CF to hold cash flows
CF = []
# Calculate the coupon payment each year
for i in range(6):
    CF.append(1000*0.08)
# Add the principal payment to the last year
CF[-1] += 1000

# create the present value of each cash flow
PV_CF = []
for i in range(len(CF)):
    PV_CF.append(CF[i]/(1+0.08)**(i+1))

# Calculate Macaulay Duration
duration = 0
for i in range(len(PV_CF)):
    duration += PV_CF[i]*(i+1)/1000
print("the Macaulay Duration is", duration)
# Out:
# the Macaulay Duration is 4.9927100370780835

# %%
# Define values
duration_asset = 5
duration_liability = 3
assets = 100
liabilities = 90
delta_R = 0.01
R = 0.1

# Calculate change in interest income
delta_income = duration_asset*assets*delta_R/(1+R)
print("the change in interest income is", delta_income)

# Calculate change in interest liabilities
delta_liability = duration_liability*liabilities*delta_R/(1+R)
print("the change in interest liability is", delta_liability)

# Calculate shareholder value change
delta_equity = delta_income - delta_liability
print("the change in shareholder value is", delta_equity)
# Out:
# the change in interest income is 4.545454545454545
# the change in interest liability is 2.4545454545454546
# the change in shareholder value is 2.0909090909090904

# %%
import numpy as np
import matplotlib.pyplot as plt

rate = np.linspace(3.5,7,1000) 
interest = np.zeros((1000,))

for i in range(1000):
    interest[i] = - 100*rate[i]/100

fig = plt.figure(dpi=128, figsize=(10,6))
axes = plt.gca()
axes.set_xlim([3.5,7.5])
axes.set_ylim([-7,-2])
axes.spines['bottom'].set_position(('data', -5))

axes.spines['right'].set_color('none')
axes.spines['top'].set_color('none')

x1 = np.array([3.5,4])
y1 = np.array([-4,-4])
x2 = np.array([4,4])
y2 = np.array([-4,-5])

plt.plot(x1, y1, '--',color='orange')
plt.plot(x2, y2, '--',color='orange')

x3 = np.array([3.5,4.5])
y3 = np.array([-4.5,-4.5])
x4 = np.array([4.5,4.5])
y4 = np.array([-4.5,-5])

plt.plot(x3, y3, '--',color='orange')
plt.plot(x4, y4, '--',color='orange')

x5 = np.array([3.5,5.5])
y5 = np.array([-5.5,-5.5])
x6 = np.array([5.5,5.5])
y6 = np.array([-5,-5.5])

plt.plot(x5, y5, '--',color='orange')
plt.plot(x6, y6, '--',color='orange')

x7 = np.array([3.5,6])
y7 = np.array([-6,-6])
x8 = np.array([6,6])
y8 = np.array([-5,-6])

plt.plot(x7, y7, '--',color='orange')
plt.plot(x8, y8, '--',color='orange')

plt.plot(rate, interest, color='blue', linewidth = '5')
plt.xlabel('                                                             interest rate %',fontsize=12)
plt.ylabel('Interest Payment ($million)',fontsize=12)
plt.title('Expected Interest Payment As a Function of Market Rate',fontsize=14)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rate = np.linspace(3.5,7,1000) 
interest = np.zeros((1000,))

for i in range(1000):
    interest[i] = 100*(rate[i]-5)/100

fig = plt.figure(dpi=128, figsize=(10,6))
axes = plt.gca()
axes.set_xlim([3.5,7.5])
axes.set_ylim([-2,2])
axes.spines['bottom'].set_position('center')

axes.spines['right'].set_color('none')
axes.spines['top'].set_color('none')

x1 = np.array([3.5,4])
y1 = np.array([-1,-1])
x2 = np.array([4,4])
y2 = np.array([-1,0])

plt.plot(x1, y1, '--',color='orange')
plt.plot(x2, y2, '--',color='orange')

x3 = np.array([3.5,4.5])
y3 = np.array([-0.5,-0.5])
x4 = np.array([4.5,4.5])
y4 = np.array([-0.5,0])

plt.plot(x3, y3, '--',color='orange')
plt.plot(x4, y4, '--',color='orange')

x5 = np.array([3.5,5.5])
y5 = np.array([0.5,0.5])
x6 = np.array([5.5,5.5])
y6 = np.array([0,0.5])

plt.plot(x5, y5, '--',color='orange')
plt.plot(x6, y6, '--',color='orange')

x7 = np.array([3.5,6])
y7 = np.array([1,1])
x8 = np.array([6,6])
y8 = np.array([0,1])

plt.plot(x7, y7, '--',color='orange')
plt.plot(x8, y8, '--',color='orange')

plt.plot(rate, interest, color='blue', linewidth = '5')
plt.xlabel('                               market interest rate (in percentage)',fontsize=12)
plt.ylabel('Interest Payments ($million)',fontsize=12)
plt.title('Expected Interest Payments a Function of Market Rate',fontsize=14)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

rate = np.linspace(3.5,7,1000) 
interest = np.zeros((1000,))

for i in range(1000):
    interest[i] = -5

fig = plt.figure(dpi=128, figsize=(10,6))
axes = plt.gca()
axes.set_xlim([3.5,7.5])
axes.set_ylim([-6,0])
axes.spines['bottom'].set_position(('data',0))

axes.spines['right'].set_color('none')
axes.spines['top'].set_color('none')


plt.plot(rate, interest, color='blue', linewidth = '5')
plt.xlabel('                               market interest rate (in percentage)',fontsize=12)
plt.ylabel('Interest Payments ($million)',fontsize=12)
plt.title('Expected Interest Payments After Hedging',fontsize=14)

plt.show()

# %%
loan=100
margin=0.02

def net(s):
    net_value=loan*(margin+s)-5
    return net_value

result=net(0.02)
print('Net payment when SOFR is 0.02 =', result)
result=net(0.05)
print('Net payment when SOFR is 0.05=', result)
# Out:
# Net payment when SOFR is 0.02 = -1.0
# Net payment when SOFR is 0.05= 2.000000000000001

# %% [markdown]
# Question 1:

# %%
RSA = 1000+1000+400
print("the amount of rate sensitive assets is", RSA)
RSL = 800+500+400
print("the amount of rate sensitive liabilities is", RSL)
GAP = RSA-RSL
print("the repricing gap is", GAP)
delta_R = 0.02
delta_NII = GAP*delta_R
print("the change in net interest income is", delta_NII)
# Out:
# the amount of rate sensitive assets is 2400
# the amount of rate sensitive liabilities is 1700
# the repricing gap is 700
# the change in net interest income is 14.0

# %%
Question 2:

# %%
# Create a list CF to hold cash flows
CF = []
# Calculate the coupon payment each year
for i in range(10):
    CF.append(1000*0.04)
# Add the principal payment to the last year
CF[-1] += 1000

# create the present value of each cash flow
PV_CF = []
for i in range(len(CF)):
    PV_CF.append(CF[i]/(1+0.05)**(i+1))

# Calculate Macaulay Duration
duration = 0
for i in range(len(PV_CF)):
    duration += PV_CF[i]*(i+1)/1000
print("the Macaulay Duration is", duration)  
modified_duration = duration/(1+0.05)
print("the Modified Duration is", modified_duration)
# Out:
# the Macaulay Duration is 7.7140838475967595
# the Modified Duration is 7.346746521520723

# %%
Question 3:

# %%
# Define values
duration_asset = 10
duration_liability = 5
assets = 1200
liabilities = 1000
delta_R = 0.005
R = 0.1

# Calculate change in interest income
delta_income = duration_asset*assets*delta_R/(1+R)
print("the change in interest income is", delta_income)

# Calculate change in interest liabilities
delta_liability = duration_liability*liabilities*delta_R/(1+R)
print("the change in interest liability is", delta_liability)

# Calculate shareholder value change
delta_equity = delta_income - delta_liability
print("the change in shareholder value is", delta_equity)
# Out:
# the change in interest income is 54.54545454545454
# the change in interest liability is 22.727272727272727
# the change in shareholder value is 31.818181818181813

# %% [markdown]
# Question 4:

# %%
optimal_DA = duration_liability*liabilities/assets
print("the optimal asset modified duration is", optimal_DA)
# Out:
# the optimal asset modified duration is 4.166666666666667

# %% [markdown]
# Question 6:

# %%
'''
Enter into ten FRAs. Each year in the next ten years, you'll pay $1.2m in exchange for 
the interest payment on $30m at the prevailing market rate.

# At the end of each year, your interest payment on the load is
interest payment = -$30m * R, where R is the market interest rate

Your gain/loss from the FRA each year is
forward_payoff = $30m * R - 1.2

The sum of the above two is

interest payment + forward_payoff = -$30m * R + $30m * R - 1.2 = 1.2m$

which is a fixed amount

'''

# %% [markdown]
# Question 7:

# %%
'''
To hedge the interest risk, you can enter into one single interest rate swap with your counterparty. 
The contract specifies that at the end of each year in the next ten years, 
you’ll pay $1.2m to your counterparty, in exchange for the floating interest payment on a $30m loan
at the prevailing market interest rate at the end of that year. 
'''
